# %% [markdown]
# <a href="https://colab.research.google.com/github/nahumsa/DM-Reconstruction/blob/master/Analysis%20Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysis of Results of Reconstruction of Density Matrices using AutoEncoders and Variational AutoEncoders

# %% [markdown]
# ##Import dependencies for Google Colab

# %%
from IPython.display import clear_output

! git clone https://github.com/nahumsa/DM-Reconstruction
% cd DM-Reconstruction/
clear_output()

# %% [markdown]
# ## Importing Dependencies for plotting

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()
clear_output()

# %%
sns.set_context("paper", font_scale=1., rc={"lines.linewidth": 2.5})

# %% [markdown]
# # Analysing AutoEncoders

# %% [markdown]
# ## Importing the values

# %%
AE_Fidelity = np.loadtxt('Results/AE/AE_Fidelity.txt')
AE_Loss = np.loadtxt('Results/AE/AE_Loss.txt')
AE_val_Fidelity = np.loadtxt('Results/AE/val_AE_Fidelity.txt')
AE_val_Loss = np.loadtxt('Results/AE/val_AE_Loss.txt')

# %%
TAE_Fidelity = np.loadtxt('Results/TAE/TAE_Fidelity.txt')
TAE_Loss = np.loadtxt('Results/TAE/TAE_Loss.txt')
TAE_val_Fidelity = np.loadtxt('Results/TAE/val_TAE_Fidelity.txt')
TAE_val_Loss = np.loadtxt('Results/TAE/val_TAE_Loss.txt')

# %%
TVAE_Fidelity = np.loadtxt('Results/TVAE/TVAE_Fidelity.txt')
TVAE_Loss = np.loadtxt('Results/TVAE/TVAE_Loss.txt')
TVAE_val_Fidelity = np.loadtxt('Results/TVAE/val_TVAE_Fidelity.txt')
TVAE_val_Loss = np.loadtxt('Results/TVAE/val_TVAE_Loss.txt')

# %%
epochs_TAE = range(len(TAE_Fidelity))
epochs_TVAE = range(len(TVAE_Fidelity))
epochs_AE = range(len(AE_Fidelity))

# %% [markdown]
# ## Plotting

# %%
fig = plt.figure(figsize=(14,10))
gs = fig.add_gridspec(1, 1)
ax1 = fig.add_subplot(gs[0, 0])


fig.suptitle('Fidelity', size=16)

ax1.plot(epochs_AE, AE_Fidelity, 'r', label='AE')
ax1.plot(epochs_AE, AE_val_Fidelity, 'r:')

ax1.plot(epochs_TAE, TAE_Fidelity, 'b', label='TAE')
ax1.plot(epochs_TAE, TAE_val_Fidelity, 'b:')

ax1.plot(epochs_TVAE, TVAE_Fidelity, 'g', label='TVAE')
ax1.plot(epochs_TVAE, TVAE_val_Fidelity, 'g:')

ax1.set_xlabel('Epochs')
ax1.set_ylabel('Fidelity')
ax1.legend()

plt.show()

# %% [markdown]
# ## Errors

# %% [markdown]
# ### Importing

# %%
AE_Fidelity_pi6     = np.loadtxt('Results/Error/AE_pi6/AE_Fidelity.txt')
AE_Loss_pi6         = np.loadtxt('Results/Error/AE_pi6/AE_Loss.txt')
AE_val_Fidelity_pi6 = np.loadtxt('Results/Error/AE_pi6/val_AE_Fidelity.txt')
AE_val_Loss_pi6     = np.loadtxt('Results/Error/AE_pi6/val_AE_Loss.txt')

AE_Fidelity_pi4     = np.loadtxt('Results/Error/AE_pi4/AE_Fidelity.txt')
AE_Loss_pi4         = np.loadtxt('Results/Error/AE_pi4/AE_Loss.txt')
AE_val_Fidelity_pi4 = np.loadtxt('Results/Error/AE_pi4/val_AE_Fidelity.txt')
AE_val_Loss_pi4     = np.loadtxt('Results/Error/AE_pi4/val_AE_Loss.txt')

AE_Fidelity_pi2     = np.loadtxt('Results/Error/AE_pi2/AE_Fidelity.txt')
AE_Loss_pi2         = np.loadtxt('Results/Error/AE_pi2/AE_Loss.txt')
AE_val_Fidelity_pi2 = np.loadtxt('Results/Error/AE_pi2/val_AE_Fidelity.txt')
AE_val_Loss_pi2     = np.loadtxt('Results/Error/AE_pi2/val_AE_Loss.txt')

AE_Fidelity_pi      = np.loadtxt('Results/Error/AE_pi/AE_Fidelity.txt')
AE_Loss_pi          = np.loadtxt('Results/Error/AE_pi/AE_Loss.txt')
AE_val_Fidelity_pi  = np.loadtxt('Results/Error/AE_pi/val_AE_Fidelity.txt')
AE_val_Loss_pi      = np.loadtxt('Results/Error/AE_pi/val_AE_Loss.txt')

# %%
TAE_Fidelity_pi6     = np.loadtxt('Results/Error/TAE_pi6/TAE_Fidelity.txt')
TAE_Loss_pi6         = np.loadtxt('Results/Error/TAE_pi6/TAE_Loss.txt')
TAE_val_Fidelity_pi6 = np.loadtxt('Results/Error/TAE_pi6/val_TAE_Fidelity.txt')
TAE_val_Loss_pi6     = np.loadtxt('Results/Error/TAE_pi6/val_TAE_Loss.txt')

TAE_Fidelity_pi4     = np.loadtxt('Results/Error/TAE_pi4/TAE_Fidelity.txt')
TAE_Loss_pi4         = np.loadtxt('Results/Error/TAE_pi4/TAE_Loss.txt')
TAE_val_Fidelity_pi4 = np.loadtxt('Results/Error/TAE_pi4/val_TAE_Fidelity.txt')
TAE_val_Loss_pi4     = np.loadtxt('Results/Error/TAE_pi4/val_TAE_Loss.txt')

TAE_Fidelity_pi2     = np.loadtxt('Results/Error/TAE_pi2/TAE_Fidelity.txt')
TAE_Loss_pi2         = np.loadtxt('Results/Error/TAE_pi2/TAE_Loss.txt')
TAE_val_Fidelity_pi2 = np.loadtxt('Results/Error/TAE_pi2/val_TAE_Fidelity.txt')
TAE_val_Loss_pi2     = np.loadtxt('Results/Error/TAE_pi2/val_TAE_Loss.txt')

TAE_Fidelity_pi      = np.loadtxt('Results/Error/TAE_pi/TAE_Fidelity.txt')
TAE_Loss_pi          = np.loadtxt('Results/Error/TAE_pi/TAE_Loss.txt')
TAE_val_Fidelity_pi  = np.loadtxt('Results/Error/TAE_pi/val_TAE_Fidelity.txt')
TAE_val_Loss_pi      = np.loadtxt('Results/Error/TAE_pi/val_TAE_Loss.txt')

# %%
TVAE_Fidelity_pi6     = np.loadtxt('Results/Error/TVAE_pi6/TVAE_Fidelity.txt')
TVAE_Loss_pi6         = np.loadtxt('Results/Error/TVAE_pi6/TVAE_Loss.txt')
TVAE_val_Fidelity_pi6 = np.loadtxt('Results/Error/TVAE_pi6/val_TVAE_Fidelity.txt')
TVAE_val_Loss_pi6     = np.loadtxt('Results/Error/TVAE_pi6/val_TVAE_Loss.txt')

TVAE_Fidelity_pi4     = np.loadtxt('Results/Error/TVAE_pi4/TVAE_Fidelity.txt')
TVAE_Loss_pi4         = np.loadtxt('Results/Error/TVAE_pi4/TVAE_Loss.txt')
TVAE_val_Fidelity_pi4 = np.loadtxt('Results/Error/TVAE_pi4/val_TVAE_Fidelity.txt')
TVAE_val_Loss_pi4     = np.loadtxt('Results/Error/TVAE_pi4/val_TVAE_Loss.txt')

TVAE_Fidelity_pi2     = np.loadtxt('Results/Error/TVAE_pi2/TVAE_Fidelity.txt')
TVAE_Loss_pi2         = np.loadtxt('Results/Error/TVAE_pi2/TVAE_Loss.txt')
TVAE_val_Fidelity_pi2 = np.loadtxt('Results/Error/TVAE_pi2/val_TVAE_Fidelity.txt')
TVAE_val_Loss_pi2     = np.loadtxt('Results/Error/TVAE_pi2/val_TVAE_Loss.txt')

TVAE_Fidelity_pi      = np.loadtxt('Results/Error/TVAE_pi/TVAE_Fidelity.txt')
TVAE_Loss_pi          = np.loadtxt('Results/Error/TVAE_pi/TVAE_Loss.txt')
TVAE_val_Fidelity_pi  = np.loadtxt('Results/Error/TVAE_pi/val_TVAE_Fidelity.txt')
TVAE_val_Loss_pi      = np.loadtxt('Results/Error/TVAE_pi/val_TVAE_Loss.txt')

# %%
last = lambda x: x[-1]

x_pi = [1., .5, .25, 1/6]

AE_fid = [last(AE_Fidelity_pi), last(AE_Fidelity_pi2), 
        last(AE_Fidelity_pi4), last(AE_Fidelity_pi6)]

AE_val_fid = [last(AE_val_Fidelity_pi), last(AE_val_Fidelity_pi2), 
        last(AE_val_Fidelity_pi4), last(AE_val_Fidelity_pi6)]

TAE_fid = [last(TAE_Fidelity_pi), last(TAE_Fidelity_pi2), 
        last(TAE_Fidelity_pi4), last(TAE_Fidelity_pi6)]

TAE_val_fid = [last(TAE_val_Fidelity_pi), last(TAE_val_Fidelity_pi2), 
        last(TAE_val_Fidelity_pi4), last(TAE_val_Fidelity_pi6)]

TVAE_fid = [last(TVAE_Fidelity_pi), last(TVAE_Fidelity_pi2), 
        last(TVAE_Fidelity_pi4), last(TVAE_Fidelity_pi6)]

TVAE_val_fid = [last(TVAE_val_Fidelity_pi), last(TVAE_val_Fidelity_pi2), 
        last(TVAE_val_Fidelity_pi4), last(TVAE_val_Fidelity_pi6)]

# %% [markdown]
# ### Plotting

# %%
def fractions(x,pos):
    if np.isclose((x/step)%(1./step),0.):        
        if x == 1:
          return '$\pi$'.format(x) 
          
        return '${:.0f} \pi$'.format(x)
    else:        
        return '$\\frac{{{:2.0f}\pi}}{{{:2.0f}}}$'.format(x/step,1./step)

# %%
import matplotlib.ticker as tck

fig = plt.figure(figsize=(14,10))
gs = fig.add_gridspec(1, 1)
ax1 = fig.add_subplot(gs[0, 0])

# ax1.xaxis.set_major_formatter(tck.FormatStrFormatter('%g $\pi$'))
step = 1/4
ax1.xaxis.set_major_locator(tck.MultipleLocator(step))
ax1.xaxis.set_major_formatter(tck.FuncFormatter(fractions))
for tick in ax1.xaxis.get_major_ticks():
    tick.label.set_fontsize(20) 
for tick in ax1.yaxis.get_major_ticks():
    tick.label.set_fontsize(20) 

fig.suptitle('Fidelity', size=24)

ax1.plot(x_pi, AE_fid, 'r', label='AE')
ax1.plot(x_pi, AE_val_fid, 'r:')

ax1.plot(x_pi, TAE_fid, 'b', label='TAE')
ax1.plot(x_pi, TAE_val_fid, 'b:')

ax1.plot(x_pi, TVAE_fid, 'g', label='TVAE')
ax1.plot(x_pi, TVAE_val_fid, 'g:')

ax1.set_xlabel('Error', size=20)
ax1.set_ylabel('Fidelity', size=20)
ax1.legend(prop={'size':20})

plt.show()
